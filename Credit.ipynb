# %%
import pandas as pd

# %%
data=pd.read_csv('E:\CREDIT_PROJECT\Data\german_credit_data.csv')
data
# Out:
#      laufkont  laufzeit  moral  verw  hoehe  sparkont  beszeit  rate  famges  \
# 0           1        18      4     2   1049         1        2     4       2
# 1           1         9      4     0   2799         1        3     2       3
# 2           2        12      2     9    841         2        4     2       2
# 3           1        12      4     0   2122         1        3     3       3
# 4           1        12      4     0   2171         1        3     4       3
# ..        ...       ...    ...   ...    ...       ...      ...   ...     ...
# 995         1        24      2     3   1987         1        3     2       3
# 996         1        24      2     0   2303         1        5     4       3
# 997         4        21      4     0  12680         5        5     4       3
# 998         2        12      2     3   6468         5        1     2       3
# 999         1        30      2     2   6350         5        5     4       3
#
# ...

# %% [markdown]
# replaced columns names from German to Eng

# %%
data.rename(columns={
    "laufkont": "checking_account",
    "laufzeit": "duration_months",
    "moral": "credit_history",
    "verw": "purpose",
    "hoehe": "credit_amount",
    "sparkont": "savings_account",
    "beszeit": "employment_duration",
    "rate": "installment_rate",
    "famges": "personal_status_sex",
    "buerge": "guarantor",
    "wohnzeit": "residence_duration",
    "verm": "property",
    "alter": "age",
    "weitkred": "other_credits",
    "wohn": "housing",
    "bishkred": "existing_credits",
    "beruf": "job",
    "pers": "people_liable",
    "telef": "telephone",
    "gastarb": "foreign_worker",
    "kredit": "risk"
}, inplace=True)
data
# Out:
#      checking_account  duration_months  credit_history  purpose  \
# 0                   1               18               4        2
# 1                   1                9               4        0
# 2                   2               12               2        9
# 3                   1               12               4        0
# 4                   1               12               4        0
# ..                ...              ...             ...      ...
# 995                 1               24               2        3
# 996                 1               24               2        0
# 997                 4               21               4        0
# 998                 2               12               2        3
# 999                 1               30               2        2
#
#      credit_amount  savings_account  employment_duration  installment_rate  \
# 0             1049                1                    2                 4
# ...

# %% [markdown]
# Checking the size of the data set

# %%
data.shape
# Out:
# (1000, 21)

# %% [markdown]
# Checking duplicate rows

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# checking outliers

# %%
data.describe
# Out:
# <bound method NDFrame.describe of      checking_account  duration_months  credit_history  purpose  \
# 0                   1               18               4        2
# 1                   1                9               4        0
# 2                   2               12               2        9
# 3                   1               12               4        0
# 4                   1               12               4        0
# ..                ...              ...             ...      ...
# 995                 1               24               2        3
# 996                 1               24               2        0
# 997                 4               21               4        0
# 998                 2               12               2        3
# 999                 1               30               2        2
#
#      credit_amount  savings_account  employment_duration  installment_rate  \
# 0             1049                1                    2                 4
# ...

# %% [markdown]
# checking missing values

# %%
data.isnull().sum()
# Out:
# checking_account       0
# duration_months        0
# credit_history         0
# purpose                0
# credit_amount          0
# savings_account        0
# employment_duration    0
# installment_rate       0
# personal_status_sex    0
# guarantor              0
# residence_duration     0
# property               0
# age                    0
# other_credits          0
# housing                0
# existing_credits       0
# job                    0
# people_liable          0
# telephone              0
# foreign_worker         0
# risk                   0
# dtype: int64

# %% [markdown]
# Checking data types of every column

# %%
data.dtypes
# Out:
# checking_account       int64
# duration_months        int64
# credit_history         int64
# purpose                int64
# credit_amount          int64
# savings_account        int64
# employment_duration    int64
# installment_rate       int64
# personal_status_sex    int64
# guarantor              int64
# residence_duration     int64
# property               int64
# age                    int64
# other_credits          int64
# housing                int64
# existing_credits       int64
# job                    int64
# people_liable          int64
# telephone              int64
# foreign_worker         int64
# risk                   int64
# dtype: object

# %% [markdown]
# Checking Imbalanced Data

# %%
data.risk.value_counts()
# Out:
# risk
# 1    700
# 0    300
# Name: count, dtype: int64

# %%
import seaborn as sn
import matplotlib.pyplot as plt

sn.countplot(x="risk",data=data)
plt.title("Distribution Of Target Variable")
plt.show()

# %% [markdown]
# checking cardinality of catogorical columns

# %%
data.nunique()
# Out:
# checking_account         4
# duration_months         33
# credit_history           5
# purpose                 10
# credit_amount          923
# savings_account          5
# employment_duration      5
# installment_rate         4
# personal_status_sex      4
# guarantor                3
# residence_duration       4
# property                 4
# age                     53
# other_credits            3
# housing                  3
# existing_credits         4
# job                      4
# people_liable            2
# telephone                2
# foreign_worker           2
# risk                     2
# dtype: int64

# %% [markdown]
# DAY 2

# %%
x=data.drop("risk",axis=1)
y=data["risk"]

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# Feature scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test=scaler.transform(x_test)

# %% [markdown]
# #Balancing the data using SMOTE

# %%
from imblearn.over_sampling import SMOTE

smote=SMOTE(random_state=42)
x_train_rsm,y_train_rsm=smote.fit_resample(x_train,y_train)
